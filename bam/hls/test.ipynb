# %%
import sys
import os

sys.path.append("/media/jdx/jdx/FTServo_Python")

# %%
from scservo_sdk import *

# %%
portHandler = PortHandler('/dev/ttyUSB0') #ex) Windows: "COM1"   Linux: "/dev/ttyUSB0" Mac: "/dev/tty.usbserial-*"

# Initialize PacketHandler instance
# Get methods and members of Protocol
packetHandler = hls(portHandler)
# Open port
if portHandler.openPort():
    print("Succeeded to open the port")
else:
    print("Failed to open the port")
    quit()

# Set port baudrate 1000000
if portHandler.setBaudRate(1000000):
    print("Succeeded to change the baudrate")
else:
    print("Failed to change the baudrate")
    quit()
# Out:
# Succeeded to open the port
# Succeeded to change the baudrate

# %%
portHandler.closePort()

# %%
import sys
import os

sys.path.append("/media/jdx/jdx/bam/bam")

# %%
from bam.actuator import Actuator
from bam.parameter import Parameter
from bam.testbench import Testbench, Pendulum
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from bam.actuator import Actuator
#       2 from bam.parameter import Parameter
#       3 from bam.testbench import Testbench, Pendulum
#
# File /media/jdx/jdx/bam/bam/actuator.py:10
#       1 # Copyright 2025 Marc Duclusaud & Grégoire Passault
#       2
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#       6
#       7 #     http://www.apache.org/licenses/LICENSE-2.0
#       9 import numpy as np
# ---> 10 from testbench import Testbench
#      11 from parameter import Parameter
#      12 from message import yellow, print_parameter
#
# ModuleNotFoundError: No module named 'testbench'

# %%
from trajectory import *
